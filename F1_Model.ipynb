# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/F1 Races 2020-2024.csv')

# %%
df.head()
# Out:
#    year  round  circuitId        date  rainy  Turns  Length  driverId  \
# 0  2000      1          1  2000-03-12      0     14   5.278         2
# 1  2000      1          1  2000-03-12      0     14   5.278        14
# 2  2000      1          1  2000-03-12      0     14   5.278        15
# 3  2000      1          1  2000-03-12      0     14   5.278        18
# 4  2000      1          1  2000-03-12      0     14   5.278        21
#
#    constructorId  grid  ...  laps  statusId  Weighted_Top_3_Probability  \
# 0             20    15  ...    56        12                    0.087719
# 1              1     2  ...    11         5                    0.208333
# 2             17     6  ...    35         5                    0.048387
# 3              3    21  ...    46         5                    0.160494
# 4             22     9  ...    58         1                    0.076923
#
#    Weighted_Top_3_Prob_Length  position_previous_race  nro_cond_escuderia  \
# 0                    0.090909                     8.0                   2
# 1                    0.222222                    20.0                   2
# 2                    0.083333                    20.0                   2
# 3                    0.235294                    20.0                   2
# 4                    0.100000                    11.0                   1
#
#    raceId  points  prom_points_10  Top 3 Finish
# 0     158     0.0             9.4             0
# 1     158     0.0            47.6             0
# 2     158     0.0             8.5             0
# 3     158     0.0             1.2             0
# 4     158     2.0             4.5             0
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9839 entries, 0 to 9838
# Data columns (total 34 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   year                                                            9839 non-null   int64
#  1   round                                                           9839 non-null   int64
#  2   circuitId                                                       9839 non-null   int64
#  3   date                                                            9839 non-null   object
#  4   rainy                                                           9839 non-null   int64
#  5   Turns                                                           9839 non-null   int64
#  6   Length                                                          9839 non-null   float64
#  7   driverId                                                        9839 non-null   int64
#  8   constructorId                                                   9839 non-null   int64
#  9   grid                                                            9839 non-null   int64
#  10  Driver Top 3 Finish Percentage (Last Year)                      9839 non-null   float64
#  11  Constructor Top 3 Finish Percentage (Last Year)                 9839 non-null   float64
#  12  Driver Top 3 Finish Percentage (This Year till last race)       9839 non-null   float64
#  13  Constructor Top 3 Finish Percentage (This Year till last race)  9839 non-null   float64
#  14  Driver Avg position (Last Year)                                 9839 non-null   float64
#  15  Constructor Avg position (Last Year)                            9839 non-null   float64
#  16  Driver Average Position (This Year till last race)              9839 non-null   float64
#  17  Constructor Average Position (This Year till last race)         9839 non-null   float64
#  18  driver_age                                                      9839 non-null   int64
#  19  nationality_encoded                                             9839 non-null   int64
#  20  wins_cons                                                       9839 non-null   float64
#  21  points_cons_champ                                               9839 non-null   float64
#  22  wins                                                            9839 non-null   float64
#  23  points_driver_champ                                             9839 non-null   float64
#  24  laps                                                            9839 non-null   int64
#  25  statusId                                                        9839 non-null   int64
#  26  Weighted_Top_3_Probability                                      9839 non-null   float64
#  27  Weighted_Top_3_Prob_Length                                      9839 non-null   float64
#  28  position_previous_race                                          9839 non-null   float64
#  29  nro_cond_escuderia                                              9839 non-null   int64
#  30  raceId                                                          9839 non-null   int64
#  31  points                                                          9839 non-null   float64
#  32  prom_points_10                                                  9839 non-null   float64
#  33  Top 3 Finish                                                    9839 non-null   int64
# dtypes: float64(18), int64(15), object(1)
# memory usage: 2.6+ MB

# %%
df.shape
# Out:
# (9839, 34)

# %%
missing_values = df.isnull().sum()

# %%
print(missing_values)
# Out:
# year                                                              0
# round                                                             0
# circuitId                                                         0
# date                                                              0
# rainy                                                             0
# Turns                                                             0
# Length                                                            0
# driverId                                                          0
# constructorId                                                     0
# grid                                                              0
# Driver Top 3 Finish Percentage (Last Year)                        0
# Constructor Top 3 Finish Percentage (Last Year)                   0
# Driver Top 3 Finish Percentage (This Year till last race)         0
# Constructor Top 3 Finish Percentage (This Year till last race)    0
# Driver Avg position (Last Year)                                   0
# Constructor Avg position (Last Year)                              0
# Driver Average Position (This Year till last race)                0
# Constructor Average Position (This Year till last race)           0
# driver_age                                                        0
# nationality_encoded                                               0
# wins_cons                                                         0
# points_cons_champ                                                 0
# wins                                                              0
# points_driver_champ                                               0
# laps                                                              0
# statusId                                                          0
# Weighted_Top_3_Probability                                        0
# Weighted_Top_3_Prob_Length                                        0
# position_previous_race                                            0
# nro_cond_escuderia                                                0
# raceId                                                            0
# points                                                            0
# prom_points_10                                                    0
# Top 3 Finish                                                      0
# dtype: int64

# %%
features = ['grid','rainy','Driver Average Position (This Year till last race)','Constructor Average Position (This Year till last race)','laps','driver_age']

# %%
target = 'points'

# %%
X = df[features]
y = df[target]

# %%
X.head()
# Out:
#    grid  rainy  Driver Average Position (This Year till last race)  \
# 0    15      0                                                0.0
# 1     2      0                                                0.0
# 2     6      0                                                0.0
# 3    21      0                                                0.0
# 4     9      0                                                0.0
#
#    Constructor Average Position (This Year till last race)  laps  driver_age
# 0                                                0.0          56          23
# 1                                                0.0          11          29
# 2                                                0.0          35          26
# 3                                                0.0          46          20
# 4                                                0.0          58          27

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred)
# Out:
# [ 42.09633926 103.59988592  73.59469193 ...  39.357452    66.08698848
#   87.15209235]

# %%
print(y_test)
# Out:
# 6718      0.0
# 4254    161.0
# 9027    335.0
# 9173      6.0
# 518       5.0
#         ...
# 1157      8.0
# 7784      8.0
# 1532      8.0
# 7974      6.0
# 6079    199.0
# Name: points, Length: 2952, dtype: float64

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
print(f"Mean Absolute Error (MAE): {mae:.2f} points")
# Out:
# Mean Absolute Error (MAE): 32.34 points
